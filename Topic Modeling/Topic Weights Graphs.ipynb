# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import spline

# %% [markdown]
# ## The Top 10 Words for Each Topic

# %%
topic_words = pd.read_csv("topic_words.csv", index_col=0)
topic_words
# Out:
#               word 1     word 2       word 3       word 4        word 5  \
# topic_id
# 0           american     states    officials       united      military
# 1              court       news         case       prison        family
# 2             israel    israeli  palestinian    netanyahu  palestinians
# 3             killed     attack     military      attacks      security
# 4              saudi     arabia        yemen         arab        yemeni
# 5              obama      would        kerry        trump     president
# 6          hezbollah      syria      lebanon     lebanese        syrian
# 7               iran    iranian      nuclear    sanctions        united
# 8         protesters     police     protests       people      security
# 9             turkey    kurdish      turkish       border        syrian
# 10             egypt   egyptian     military  brotherhood       mubarak
# 11           islamic      state        group         isis      fighters
# 12            rights      human        women       report         group
# 13             syria     syrian        assad      weapons    government
# 14            united    nations      council     security        states
# 15               one     people         many         like         years
# 16        government     syrian        rebel       rebels         syria
# 17              gaza      hamas       israel      israeli   palestinian
# 18        government  political     minister        would           new
# 19              iraq      iraqi       shiite        sunni       baghdad
#
#               word 6         word 7          word 8          word 9  \
# topic_id
# 0              would          obama  administration    intelligence
# 1              media            two         charges           video
# 2          jerusalem           bank            west          jewish
# 3             people            two          forces        soldiers
# 4             united      coalition         country           qaeda
# 5             united         states        american  administration
# 6             jordan       refugees             war          border
# 7             tehran         states           would           irans
# 8         government         forces          friday       activists
# 9              syria         region          united          states
# 10             morsi      president           cairo          muslim
# 11             syria           iraq       militants          forces
# 12            groups            law   international      government
# 13            russia       chemical      opposition         russian
# 14               aid  international         general          people
# 15              year           even          family           would
# 16            aleppo       fighters            city           assad
# 17          military           fire    palestinians          border
# 18             party      president           prime      parliament
# 19        government       american          forces          troops
#
#                word 10
# topic_id
# 0            official
# 1         authorities
# 2            israelis
# 3           officials
# 4                 led
# 5                deal
# 6              shiite
# 7             program
# 8            violence
# 9           officials
# 10         government
# 11               also
# 12          activists
# 13              would
# 14          countries
# 15                two
# 16           damascus
# 17               west
# 18              power
# 19           security

# %% [markdown]
# ## The Topic Weight Graphs across 2011 - 2018

# %%
month_topics = pd.read_csv("month_topics.csv")

# %% [markdown]
# ### Split the date by topic categories

# %%
topic0 = month_topics[month_topics["topic_id"]==0]
topic1 = month_topics[month_topics["topic_id"]==1]
topic2 = month_topics[month_topics["topic_id"]==2]
topic3 = month_topics[month_topics["topic_id"]==3]
topic4 = month_topics[month_topics["topic_id"]==4]
topic5 = month_topics[month_topics["topic_id"]==5]
topic6 = month_topics[month_topics["topic_id"]==6]
topic7 = month_topics[month_topics["topic_id"]==7]
topic8 = month_topics[month_topics["topic_id"]==8]
topic9 = month_topics[month_topics["topic_id"]==9]
topic10 = month_topics[month_topics["topic_id"]==10]
topic11 = month_topics[month_topics["topic_id"]==11]
topic12 = month_topics[month_topics["topic_id"]==12]
topic13 = month_topics[month_topics["topic_id"]==13]
topic14 = month_topics[month_topics["topic_id"]==14]
topic15 = month_topics[month_topics["topic_id"]==15]
topic16 = month_topics[month_topics["topic_id"]==16]
topic17 = month_topics[month_topics["topic_id"]==17]
topic18 = month_topics[month_topics["topic_id"]==18]
topic19 = month_topics[month_topics["topic_id"]==19]

# %% [markdown]
# ### Smoothe the data

# %%
num_month = 8 * 12
x = list(range(num_month))
x_new = np.linspace(0, num_month, num_month * 30)

def smooth(y):
    y_new = spline(x, y, x_new)
    return y_new

y0 = smooth(topic0.topic_weight.values)
y1 = smooth(topic1.topic_weight.values)
y2 = smooth(topic2.topic_weight.values)
y3 = smooth(topic3.topic_weight.values)
y4 = smooth(topic4.topic_weight.values)
y5 = smooth(topic5.topic_weight.values)
y6 = smooth(topic6.topic_weight.values)
y7 = smooth(topic7.topic_weight.values)
y8 = smooth(topic8.topic_weight.values)
y9 = smooth(topic9.topic_weight.values)
y10 = smooth(topic10.topic_weight.values)
y11 = smooth(topic11.topic_weight.values)
y12 = smooth(topic12.topic_weight.values)
y13 = smooth(topic13.topic_weight.values)
y14 = smooth(topic14.topic_weight.values)
y15 = smooth(topic15.topic_weight.values)
y16 = smooth(topic16.topic_weight.values)
y17 = smooth(topic17.topic_weight.values)
y18 = smooth(topic18.topic_weight.values)
y19 = smooth(topic19.topic_weight.values)
# Out:
# C:\Users\yangw\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# ## Plot the topic weights by month for each topic

# %%
def plot_graph(*ylist):
    fig, ax = plt.subplots(figsize=(16,8))
    for i, y in enumerate(ylist):
        ax.plot(x_new, y) 
    ax.grid()
    return ax

# %% [markdown]
# ### Topics 0 - 3

# %%
ax = plot_graph(y0, y1, y2, y3)
ax.legend(["topic 0", "topic 1", "topic 2", "topic 3"])

# %% [markdown]
# ### Topics 4 - 7

# %%
ax = plot_graph(y4, y5, y6, y7)
ax.legend(["topic 4", "topic 5", "topic 6", "topic 7"])

# %% [markdown]
# ### Topics 8 - 11

# %%
ax = plot_graph(y8, y9, y10, y11)
ax.legend(["topic 8", "topic 9", "topic 10", "topic 11"])

# %% [markdown]
# ### Topics 12 - 15

# %%
ax = plot_graph(y12, y13, y14, y15)
ax.legend(["topic 12", "topic 13", "topic 14", "topic 15"])

# %% [markdown]
# ### Topics 16 - 19

# %%
ax = plot_graph(y16, y17, y18, y19)
ax.legend(["topic 16", "topic 17", "topic 18", "topic 19"])
